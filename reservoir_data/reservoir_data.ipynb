# %%
import pandas as pd
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
from matplotlib import rcParams
import numpy as np

# %%
df = pd.read_csv('san-antonio.csv', error_bad_lines=False)

# %%
ax = sns.lineplot(x="date", y="percent_full", data=df1)
plt.figure(figsize=(15,8))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-bb8839ac51b7> in <module>
# ----> 1 ax = sns.lineplot(x="date", y="percent_full", data=df1)
#       2 plt.figure(figsize=(15,8))
#
# NameError: name 'df1' is not defined

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7948 entries, 0 to 7947
# Data columns (total 5 columns):
# date                     7948 non-null datetime64[ns]
# reservoir_storage        7948 non-null int64
# conservation_storage     7948 non-null int64
# percent_full             7948 non-null float64
# conservation_capacity    7948 non-null int64
# dtypes: datetime64[ns](1), float64(1), int64(3)
# memory usage: 310.5 KB

# %%
df.head()
# Out:
#         date  reservoir_storage  conservation_storage  percent_full  \
# 0 1997-08-09             304449                254823         100.0
# 1 1997-08-10             304449                254823         100.0
# 2 1997-08-11             304449                254823         100.0
# 3 1997-08-12             304449                254823         100.0
# 4 1997-08-13             303783                254823         100.0
#
#    conservation_capacity
# 0                 254823
# 1                 254823
# 2                 254823
# 3                 254823
# 4                 254823

# %%
df.set_index('date', inplace=True)

# %%
pd.period_range('1997-08', periods=10, freq='Y')
# Out:
# PeriodIndex(['1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#              '2005', '2006'],
#             dtype='period[A-DEC]', freq='A-DEC')

# %%
df['reservoir_storage']=df['reservoir_storage'].astype(int)
df['conservation_storage']=df['conservation_storage'].astype(int)
df['percent_full']=df['percent_full'].astype(int)
df['conservation_capacity']=df['conservation_capacity'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7948 entries, 1997-08-09 to 2019-05-13
# Data columns (total 4 columns):
# reservoir_storage        7948 non-null int64
# conservation_storage     7948 non-null int64
# percent_full             7948 non-null int64
# conservation_capacity    7948 non-null int64
# dtypes: int64(4)
# memory usage: 310.5 KB

# %%
ax = sns.lineplot(x="date", y="percent_full", data=df1)
plt.figure(figsize=(15,8))

df['1997':].percent_full.resample('y').agg('sum')

# %%
df.head()

# %%
yearly = pd.DataFrame(df['1997':].percent_full.resample('y').agg('mean'))
yearly['date']=yearly.index

quarterly = pd.DataFrame(df['1997':].percent_full.resample('q').agg('mean'))
quarterly['date']=quarterly.index

monthly = pd.DataFrame(df['1997':].percent_full.resample('m').agg('mean'))
monthly['date']=monthly.index

daily = pd.DataFrame(df['1997':].percent_full.resample('d').agg('mean'))
daily['date']=daily.index

daily_90s = pd.DataFrame(df['1997':'1999'].percent_full.resample('d').agg('mean'))
daily_90s['date']=daily_90s.index

daily_res_90s = pd.DataFrame(df['1997':'1999'].reservoir_storage.resample('d').agg('mean'))
daily_res_90s['date']=daily_res_90s.index

yearly_res = pd.DataFrame(df['1997':].reservoir_storage.resample('y').agg('mean'))
yearly_res['date']=yearly_res.index

quarterly_res = pd.DataFrame(df['1997':].reservoir_storage.resample('q').agg('mean'))
quarterly_res['date']=quarterly_res.index

quarterly_res_draught = pd.DataFrame(df['2010':'2016'].reservoir_storage.resample('q').agg('mean'))
quarterly_res_draught['date']=quarterly_res_draught.index

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
ax = sns.lineplot(x='date', y="percent_full", data=quarterly)

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
ax = sns.lineplot(x='date', y="reservoir_storage", data=quarterly_res_draught)

# %%
df2['date']=df2.index

# %%
df2
# Out:
#             percent_full       date
# date
# 1997-09-30          5300 1997-09-30
# 1997-12-31          9146 1997-12-31
# 1998-03-31          8806 1998-03-31
# 1998-06-30          8776 1998-06-30
# 1998-09-30          8731 1998-09-30
# 1998-12-31          8598 1998-12-31
# 1999-03-31          8274 1999-03-31
# 1999-06-30          8235 1999-06-30
# 1999-09-30          8188 1999-09-30
# 1999-12-31          7623 1999-12-31
# 2000-03-31          6754 2000-03-31
# 2000-06-30          5797 2000-06-30
# 2000-09-30          4507 2000-09-30
# 2000-12-31          5487 2000-12-31
# 2001-03-31          7318 2001-03-31
# 2001-06-30          8802 2001-06-30
# 2001-09-30          8338 2001-09-30
# 2001-12-31          8779 2001-12-31
# 2002-03-31          8895 2002-03-31
# 2002-06-30          8349 2002-06-30
# 2002-09-30          9174 2002-09-30
# 2002-12-31          9200 2002-12-31
# 2003-03-31          8999 2003-03-31
# 2003-06-30          8937 2003-06-30
# 2003-09-30          8823 2003-09-30
# ...
